# %% [markdown]
# <a href="https://colab.research.google.com/github/JMindpalace/codestate_section3_project/blob/main/2.%20Metabase%20%EB%8C%80%EC%8B%9C%EB%B3%B4%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Metabase

# %% [markdown]
# ## Metabase 기본 설정

# %%
docker run -p 3000:3000 --name metabase metabase/metabse # Metabase를 docker로 실행

# http://localhost:3000/으로 입장하여 metabase 기본 정보 입력(로그인 등)

# %% [markdown]
# ## Metabase에 DB 연결

# %%
docker cp ./diseasedb.db metabase:/app # DB를 metabase에 복사하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Metabase에 쿼리문으로 질의 후 대시보드 작성

# %% [markdown]
# ![image.png](data:image/png;base64,...)
